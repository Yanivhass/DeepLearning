# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Part 5: Convolutional Architecture Experiments
# <a id=part5></a>

# %% [markdown]
# In this part we will explore convolution networks and the effects of their architecture on accuracy. We'll use our deep CNN implementation and perform various experiments on it while varying the architecture. Then we'll implement our own custom architecture to see whether we can get high classification results on a large subset of CIFAR-10.
#
# Training will be performed on GPU.

# %%
import os
import re
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
seed = 42
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()

# %% [markdown]
# ## Experimenting with model architectures
# <a id=part5_3></a>

# %% [markdown]
# We will now perform a series of experiments that train various model configurations on a part of the CIFAR-10 dataset.
#
# To perform the experiments, you'll need to use a machine with a GPU since training time might be too long otherwise.

# %% [markdown]
# ### Note about running on GPUs

# %% [markdown]
# Here's an example of running a forward pass on the GPU
# (assuming you're running this notebook on a GPU-enabled machine).

# %%
from hw2.cnn import ResNet

net = ResNet(
    in_size=(3,100,100), out_classes=10, channels=[32, 64]*3,
    pool_every=4, hidden_dims=[100]*2,
    pooling_type='avg', pooling_params=dict(kernel_size=2),
)
net = net.to(device)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).unsqueeze(0)
test_image = test_image.to(device)

test_out = net(test_image)

# %% [markdown]
# Notice how we called `.to(device)` on **both** the model and the input tensor.
# Here the `device` is a `torch.device` object that we created above. If an nvidia GPU is available on the machine you're running this on, the `device` will be `'cuda'`. When you run `.to(device)` on a model, it recursively goes over all the model parameter tensors and copies their memory to the GPU. Similarly, calling `.to(device)` on the input image also copies it.
#
# In order to train on a GPU, you need to make sure to move **all** your tensors to it. You'll get errors if you try to mix CPU and GPU tensors in a computation.

# %%
print(f'This notebook is running with device={device}')
print(f'The model parameter tensors are also on device={next(net.parameters()).device}')
print(f'The test image is also on device={test_image.device}')
print(f'The output is therefore also on device={test_out.device}')
# Out:
# This notebook is running with device=cuda
# The model parameter tensors are also on device=cuda:0
# The test image is also on device=cuda:0
# The output is therefore also on device=cuda:0

# %% [markdown]
# ### Notes on using course servers
#
# First, please read the [course servers guide](https://vistalab-technion.github.io/cs236781/assignments/hpc-servers) carefully.
#
# To run the experiments on the course servers, you can use the `py-sbatch.sh` script directly to perform a single experiment run in batch mode (since it runs python once), or use the `srun` command to do a single run in interactive mode. For example, running a single run of experiment 1 interactively (after `conda activate` of course):
#
# ```shell
# srun -c 2 --gres=gpu:1 --pty python -m hw2.experiments run-exp -n test -K 32 64 -L 2 -P 2 -H 100
# ```
#
# To perform multiple runs in batch mode with `sbatch` (e.g. for running all the configurations of an experiments), you can create your own script based on `py-sbatch.sh` and invoke whatever commands you need within it.
#
# Don't request more than **2 CPU** cores and **1 GPU** device for your runs. The code won't be able to utilize more than that anyway, so you'll see no performance gain if you do. It will only cause delays for other students using the servers.

# %% [markdown]
# ### General notes for running experiments
#
# - You can run the experiments on a different machine (e.g. the course servers) and copy the results (files)
#   to the `results` folder on your local machine.
#   This notebook will only display the results, not run the actual experiment code (except for a demo run).
# - It's important to give each experiment run a name as specified by the notebook instructions later on.
#   Each run has a `run_name` parameter that will also be the base name of the results file which this
#   notebook will expect to load.
# - You will implement the code to run the experiments in the `hw2/experiments.py` module.
#   This module has a CLI parser so that you can invoke it as a script and pass in all the
#   configuration parameters for a single experiment run.
# - You should use `python -m hw2.experiments run-exp` to run an experiment, and **not**
#   `python hw2/experiments.py run-exp`, regardless of how/where you run it.

# %% [markdown]
# ### Experiment 1: Network depth and number of filters

# %% [markdown]
# In this part we will test some different architecture configurations based on our `CNN` and `ResNet`.
# Specifically, we want to try different depths and number of features to see the effects these parameters have on the model's performance.
#
# To do this, we'll define two extra hyperparameters for our model, `K` (`filters_per_layer`) and `L` (`layers_per_block`).
# - `K` is a list, containing the number of filters we want to have in our conv layers.
# - `L` is the number of consecutive layers with the same number of filters to use.
#
# For example, if `K=[32, 64]` and `L=2` it means we want two conv layers with 32 filters followed by two conv layers with 64 filters. If we also use `pool_every=3`, the feature-extraction part of our model will be:
#
#     Conv(X,32)->ReLu->Conv(32,32)->ReLU->Conv(32,64)->ReLU->MaxPool->Conv(64,64)->ReLU
#
# We'll try various values of the `K` and `L` parameters in combination and see how each architecture trains. **All other hyperparameters are up to you**, including the choice of the optimization algorithm, the learning rate, regularization and architecture hyperparams such as `pool_every` and `hidden_dims`. Note that you should select the `pool_every` parameter wisely per experiment so that you don't end up with zero-width feature maps.
#
# You can try some short manual runs to determine some good values for the hyperparameters or implement cross-validation to do it. However, the **dataset size** you test on should be large. If you limit the number of batches, make sure to use at least 30000 training images and 5000 validation images.
#
# The important thing is that you state what you used, how you decided on it, and explain your results based on that.

# %% [markdown]
# First we need to write some code to run the experiment.
#
# **TODO**:
# 1. Implement the `cnn_experiment()` function in the `hw2/experiments.py` module.
# 1. If you haven't done so already, it would be an excellent idea to implement the **early stopping** feature of the `Trainer` class.
#
# The following block tests that your implementation works. It's also meant to show you that each experiment run creates a result file containing the parameters to reproduce and the `FitResult` object for plotting.

# %%
from hw2.experiments import load_experiment, cnn_experiment
from cs236781.plot import plot_fit

# Test experiment1 implementation on a few data samples and with a small model
cnn_experiment(
    'test_run', seed=seed, bs_train=25, batches=10, epochs=2, early_stopping=5,
    filters_per_layer=[32,64], layers_per_block=1, pool_every=1, hidden_dims=[100],
    model_type='resnet',
)

# There should now be a file 'test_run.json' in your `results/` folder.
# We can use it to load the results of the experiment.
cfg, fit_res = load_experiment('results/test_run_L1_K32-64.json')
_, _ = plot_fit(fit_res, train_test_overlay=True)

# And `cfg` contains the exact parameters to reproduce it
print('experiment config: ', cfg)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       2 from cs236781.plot import plot_fit
#       4 # Test experiment1 implementation on a few data samples and with a small model
# ----> 5 cnn_experiment(
#       6     'test_run', seed=seed, bs_train=25, batches=10, epochs=2, early_stopping=5,
#       7     filters_per_layer=[32,64], layers_per_block=1, pool_every=1, hidden_dims=[100],
#       8     model_type='resnet',
#       9 )
#      11 # There should now be a file 'test_run.json' in your `results/` folder.
#      12 # We can use it to load the results of the experiment.
#      13 cfg, fit_res = load_experiment('results/test_run_L1_K32-64.json')
#
# File C:\Projects\Deep_Learning_Course\HW2\hw2\experiments.py:133, in cnn_experiment(run_name, out_dir, seed, device, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, reg, filters_per_layer, layers_per_block, pool_every, hidden_dims, model_type, print_every, **kw)
#     127 transform_test = torchvision.transforms.Compose([
#     128     torchvision.transforms.ToTensor(),
#     129     torchvision.transforms.Normalize([0.4914, 0.4822, 0.4465],
#     130                                      [0.2023, 0.1994, 0.2010])])
#     132 ds_train = CIFAR10(root=DATA_DIR, download=True, train=True, transform=transform_train)
# --> 133 ds_test = CIFAR10(root=DATA_DIR, download=True, train=False, transform=transform_test)
#     135 if not device:
#     136     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# File ~\miniconda3\envs\cs236781-hw2\lib\site-packages\torchvision\datasets\cifar.py:68, in CIFAR10.__init__(self, root, train, transform, target_transform, download)
#      65 if download:
#      66     self.download()
# ---> 68 if not self._check_integrity():
#      69     raise RuntimeError('Dataset not found or corrupted.' +
#      70                        ' You can use download=True to download it')
#      72 if self.train:
#
# File ~\miniconda3\envs\cs236781-hw2\lib\site-packages\torchvision\datasets\cifar.py:136, in CIFAR10._check_integrity(self)
#     134     filename, md5 = fentry[0], fentry[1]
#     135     fpath = os.path.join(root, self.base_folder, filename)
# --> 136     if not check_integrity(fpath, md5):
#     137         return False
#     138 return True
#
# File ~\miniconda3\envs\cs236781-hw2\lib\site-packages\torchvision\datasets\utils.py:70, in check_integrity(fpath, md5)
#      68 if md5 is None:
#      69     return True
# ---> 70 return check_md5(fpath, md5)
#
# File ~\miniconda3\envs\cs236781-hw2\lib\site-packages\torchvision\datasets\utils.py:62, in check_md5(fpath, md5, **kwargs)
#      61 def check_md5(fpath: str, md5: str, **kwargs: Any) -> bool:
# ---> 62     return md5 == calculate_md5(fpath, **kwargs)
#
# File ~\miniconda3\envs\cs236781-hw2\lib\site-packages\torchvision\datasets\utils.py:56, in calculate_md5(fpath, chunk_size)
#      54 md5 = hashlib.md5()
#      55 with open(fpath, 'rb') as f:
# ---> 56     for chunk in iter(lambda: f.read(chunk_size), b''):
#      57         md5.update(chunk)
#      58 return md5.hexdigest()
#
# File ~\miniconda3\envs\cs236781-hw2\lib\site-packages\torchvision\datasets\utils.py:56, in calculate_md5.<locals>.<lambda>()
#      54 md5 = hashlib.md5()
#      55 with open(fpath, 'rb') as f:
# ---> 56     for chunk in iter(lambda: f.read(chunk_size), b''):
#      57         md5.update(chunk)
#      58 return md5.hexdigest()
#
# KeyboardInterrupt:

# %% [markdown]
# We'll use the following function to load multiple experiment results and plot them together.

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %% [markdown]
# #### Experiment 1.1: Varying the network depth (`L`)

# %% [markdown]
# First, we'll test the effect of the network depth on training.
#
# **Configuratons**:
# - `K=32` fixed, with `L=2,4,8,16` varying per run
# - `K=64` fixed, with `L=2,4,8,16` varying per run
#
# So 8 different runs in total.
#
# **Naming runs**:
# Each run should be named `exp1_1_L{}_K{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_1_L2_K32`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `CNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
plot_exp_results('exp1_1_L*_K32*.json')
# Out:
# common config:  {'run_name': 'exp1_1', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 200, 'bs_test': 50, 'batches': 150, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 3, 'hidden_dims': [100], 'model_type': 'cnn', 'kw': {}}

# %%
plot_exp_results('exp1_1_L*_K64*.json')
# Out:
# common config:  {'run_name': 'exp1_1', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 200, 'bs_test': 50, 'batches': 150, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 3, 'hidden_dims': [100], 'model_type': 'cnn', 'kw': {}}

# %% [markdown]
# #### Experiment 1.2: Varying the number of filters per layer (`K`)

# %% [markdown]
# Now we'll test the effect of the number of convolutional filters in each layer.
#
# **Configuratons**:
# - `L=2` fixed, with `K=[32],[64],[128],[256]` varying per run.
# - `L=4` fixed, with `K=[32],[64],[128],[256]` varying per run.
# - `L=8` fixed, with `K=[32],[64],[128],[256]` varying per run.
#
# So 12 different runs in total. To clarify, each run `K` takes the value of a list with a single element.
#
# **Naming runs**:
# Each run should be named `exp1_2_L{}_K{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_2_L2_K32`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `CNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
plot_exp_results('exp1_2_L2*.json')
# Out:
# common config:  {'run_name': 'exp1_2', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 200, 'bs_test': 50, 'batches': 150, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 3, 'hidden_dims': [100], 'model_type': 'cnn', 'kw': {}}

# %%
plot_exp_results('exp1_2_L4*.json')
# Out:
# common config:  {'run_name': 'exp1_2', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 200, 'bs_test': 50, 'batches': 150, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 3, 'hidden_dims': [100], 'model_type': 'cnn', 'kw': {}}

# %%
plot_exp_results('exp1_2_L8*.json')
# Out:
# common config:  {'run_name': 'exp1_2', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 200, 'bs_test': 50, 'batches': 150, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 3, 'hidden_dims': [100], 'model_type': 'cnn', 'kw': {}}

# %% [markdown]
# #### Experiment 1.3: Varying both the number of filters (`K`) and network depth (`L`)

# %% [markdown]
# Now we'll test the effect of the number of convolutional filters in each layer.
#
# **Configuratons**:
# - `K=[64, 128, 256]` fixed with `L=1,2,3,4` varying per run.
#
# So 4 different runs in total. To clarify, each run `K` takes the value of an array with a three elements.
#
# **Naming runs**:
# Each run should be named `exp1_3_L{}_K{}-{}-{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_3_L1_K64-128-256`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration  with the `CNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
plot_exp_results('exp1_3*.json')
# Out:
# common config:  {'run_name': 'exp1_3', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 3, 'hidden_dims': [100], 'model_type': 'cnn', 'kw': {}}

# %% [markdown]
# #### Experiment 1.4: Adding depth with Residual Networks

# %% [markdown]
# Now we'll test the effect of skip connections on the training and performance.
#
# **Configuratons**:
# - `K=[32]` fixed with `L=8,16,32` varying per run.
# - `K=[64, 128, 256]` fixed with `L=2,4,8` varying per run.
#
# So 6 different runs in total.
#
# **Naming runs**:
# Each run should be named `exp1_4_L{}_K{}-{}-{}` where the braces are placeholders for the values.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `ResNet` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
K = [[32],[64,128,256]]
L = [2,4,8]
for filters in K:
    for layers in L:
        cnn_experiment(
            f'exp1_4', seed=seed, bs_train=100, batches=300, epochs=10, early_stopping=5,
             filters_per_layer=filters, layers_per_block=layers, pool_every=layers, hidden_dims=[100],
             model_type='resnet',
        )
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# *** Output file ./results\exp1_4_L2_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# *** Output file ./results\exp1_4_L4_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# *** Output file ./results\exp1_4_L8_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# *** Output file ./results\exp1_4_L2_K64-128-256.json written
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# *** Output file ./results\exp1_4_L4_K64-128-256.json written
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/300 [00:00<?, ?it/s]
# *** Output file ./results\exp1_4_L8_K64-128-256.json written

# %%
plot_exp_results('exp1_4_L*_K32.json')
# Out:
# common config:  {'run_name': 'exp1_4', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 100, 'bs_test': 25, 'batches': 300, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 4, 'hidden_dims': [100], 'model_type': 'resnet', 'kw': {}}

# %%
plot_exp_results('exp1_4_L*_K64*.json')
# Out:
# common config:  {'run_name': 'exp1_4', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 100, 'bs_test': 25, 'batches': 30, 'epochs': 0, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 4, 'hidden_dims': [100], 'model_type': 'resnet', 'kw': {}}

# %% [markdown]
# ### Experiment 2: Custom network architecture

# %% [markdown]
# In this part you will create your own custom network architecture based on the `CNN` you've implemented.
#
# Try to overcome some of the limitations your experiment 1 results, using what you learned in the course.
#
# You are free to add whatever you like to the model, for instance
# - Batch normalization
# - Dropout layers
# - Skip connections, bottlenecks
# - Change kernel spatial sizes and strides
# - Custom blocks or ideas from known architectures (e.g. inception module)
#
# Just make sure to keep the model's `init` API identical (or maybe just add parameters).

# %% [markdown]
# **TODO**: Implement your custom architecture in the `YourCNN` class within the `hw2/cnn.py` module.

# %%
from hw2.cnn import YourCNN

net = YourCNN((3,100,100), 10, channels=[32]*4, pool_every=2, hidden_dims=[100]*2,pooling_params=dict(kernel_size=2))

print(net)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).unsqueeze(0)
test_out = net(test_image)
print('out =', test_out)
# Out:
# YourCNN(
#   (feature_extractor): Sequential(
#     (0): ResidualBlock(
#       (main_path): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (shortcut_path): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#     (1): ResidualBlock(
#       (main_path): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (shortcut_path): Sequential()
#     )
#     (2): MaxPool2d(kernel_size=100, stride=100, padding=0, dilation=1, ceil_mode=False)
#   )
#   (mlp): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): MLP(
#       (fc): Sequential(
#         (0): Linear(in_features=32, out_features=100, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=100, out_features=100, bias=True)
#         (3): ReLU()
#         (4): Linear(in_features=100, out_features=10, bias=True)
#       )
#       (out): Identity()
#     )
#   )
# )
# out = tensor([[ 20.2756,   0.2142, -11.2301,  21.9192,  13.3042,  16.2215, -20.3855,
#           13.0349,  22.1114, -18.9508]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# #### Experiment 2 Configuration

# %% [markdown]
# Run your custom model on at least the following:
#
# **Configuratons**:
# - `K=[32, 64, 128]` fixed with `L=3,6,9,12` varying per run.
#
# So 4 different runs in total. To clarify, each run `K` takes the value of an array with a three elements.
#
# If you want, you can add some extra runs following the same pattern.
# Try to see how deep a model you can train.
#
# **Naming runs**:
# Each run should be named `exp2_L{}_K{}-{}-{}-{}` where the braces are placeholders for the values. For example, the first run should be named `exp2_L3_K32-64-128`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `YourCNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
from hw2.experiments import load_experiment, cnn_experiment
K = [32, 64, 128]
L = [5]
for layers in L:
     cnn_experiment(
    f'exp2',
    seed=seed,
    bs_train=256,
    batches=500,
    epochs=200,
    early_stopping=10,
    lr=5e-3,
    reg=1e-8,
    filters_per_layer=K,
    layers_per_block=layers,
    pool_every=layers,
    hidden_dims=[100],
    model_type='ycn',
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 2/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 3/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 4/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 5/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 6/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 7/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 8/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 9/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 10/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 11/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 12/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 13/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 14/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 15/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 16/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 17/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 18/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 19/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 20/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 21/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 22/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 23/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 24/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 25/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 26/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 27/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 28/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 29/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 30/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 31/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 32/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 33/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 34/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 35/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 36/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 37/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 38/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 39/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 40/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 41/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 42/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 43/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 44/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 45/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 46/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 47/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 48/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 49/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 50/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 51/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 52/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 53/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 54/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 55/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 56/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 57/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 58/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 59/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 60/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 61/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 62/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 63/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 64/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 65/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 66/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 67/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 68/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 69/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 70/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 71/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 72/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 73/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 74/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 75/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 76/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 77/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 78/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 79/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 80/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 81/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 82/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 83/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 84/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 85/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 86/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 87/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 88/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 89/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 90/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 91/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 92/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 93/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 94/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 95/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 96/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 97/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 98/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 99/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 100/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 101/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 102/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# --- EPOCH 103/200 ---
# train_batch:   0%|          | 0/196 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/157 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       3 L = [5]
#       4 for layers in L:
# ----> 5      cnn_experiment(
#       6     f'exp2',
#       7     seed=seed,
#       8     bs_train=256,
#       9     batches=500,
#      10     epochs=200,
#      11     early_stopping=10,
#      12     lr=5e-3,
#      13     reg=1e-8,
#      14     filters_per_layer=K,
#      15     layers_per_block=layers,
#      16     pool_every=layers,
#      17     hidden_dims=[100],
#      18     model_type='ycn',
#      19 )
#
# File C:\Projects\Deep_Learning_Course\HW2\hw2\experiments.py:204, in cnn_experiment(run_name, out_dir, seed, device, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, reg, filters_per_layer, layers_per_block, pool_every, hidden_dims, model_type, print_every, **kw)
#     199 fit_res = trainer.fit(dl_train, dl_test, num_epochs=epochs, early_stopping=early_stopping, checkpoints=checkpoints,
#     200                       max_batches=batches, print_every=print_every)
#     202 # ========================
# --> 204 save_experiment(run_name, out_dir, cfg, fit_res)
#
# File C:\Projects\Deep_Learning_Course\HW2\hw2\experiments.py:215, in save_experiment(run_name, out_dir, cfg, fit_res)
#     208 output = dict(config=cfg, results=fit_res._asdict())
#     210 cfg_LK = (
#     211     f'L{cfg["layers_per_block"]}_K'
#     212     f'{"-".join(map(str, cfg["filters_per_layer"]))}'
#     213 )
#     214 LR = (
# --> 215     f'LR{cfg["lr"]}_K'
#     216     f'{"-".join(map(str, cfg["filters_per_layer"].item()))}'
#     217 )
#     218 output_filename = f"{os.path.join(out_dir, run_name)}_{cfg_LK}_{LR}.json"
#     219 os.makedirs(out_dir, exist_ok=True)
#
# AttributeError: 'list' object has no attribute 'item'

# %%
plot_exp_results('exp2*.json')
# Out:
# common config:  {'run_name': 'exp2', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 100, 'bs_test': 25, 'batches': 300, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 9, 'hidden_dims': [100], 'model_type': 'ycn', 'print_every': 1, 'kw': {}}

# %% [markdown]
# ## Questions
# <a id=part5_4></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw2/answers.py`.

# %%
from cs236781.answers import display_answer
import hw2.answers

# %% [markdown]
# ### Question 1
#
# Analyze your results from experiment 1.1. In particular,
# 1.  Explain the effect of depth on the accuracy. What depth produces the best results and why do you think that's the case?
# 1. Were there values of `L` for which the network wasn't trainable? what causes this? Suggest two things which may be done to resolve it at least partially.

# %%
display_answer(hw2.answers.part5_q1)

# %% [markdown]
# ### Question 2
#
# Analyze your results from experiment 1.2. In particular, compare to the results of experiment 1.1.

# %%
display_answer(hw2.answers.part5_q2)

# %% [markdown]
# ### Question 3
#
# Analyze your results from experiment 1.3.

# %%
display_answer(hw2.answers.part5_q3)

# %% [markdown]
# ### Question 4
#
# Analyze your results from experiment 1.4. Compare to experiment 1.1 and 1.3.

# %%
display_answer(hw2.answers.part5_q4)

# %% [markdown]
# ### Question 5
#
# 1. Explain your modifications to the architecture which you implemented in the `YourCNN` class.
# 2. Analyze the results of experiment 2. Compare to experiment 1.

# %%
display_answer(hw2.answers.part5_q5)
